# %%
from pathlib import Path
import geopandas as gpd
import matplotlib.pyplot as plt

from geoworkflow.processors.extraction.osm_highways import OSMHighwaysProcessor
from geoworkflow.schemas.osm_highways_config import OSMHighwaysConfig

import logging
logging.getLogger('geoworkflow').setLevel(logging.DEBUG)
# Out:
# /home/sjs96_file_share/miniforge3/envs/geoworkflow/lib/python3.10/site-packages/google/api_core/_python_version_support.py:266: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)

# %%
from pathlib import Path
from geoworkflow.core.logging_setup import setup_logging
from geoworkflow.processors.extraction.osm_highways import OSMHighwaysProcessor
from geoworkflow.schemas.osm_highways_config import OSMHighwaysConfig

# Configure logging to save to a file
setup_logging(
    level="INFO",
    log_file=Path("logs/osm_highways_timing.log"),  # Your timing logs will go here
    enable_console=True  # Also show in console
)

output_dir = Path("../../data/01_extracted/highways")
output_dir.mkdir(parents=True, exist_ok=True)

# Create config
config = OSMHighwaysConfig(
    aoi_file="africapolis",
    output_dir=output_dir,
    highway_types="all",  # Extract all highway types
    include_attributes=["highway", "name", "surface", "lanes"],
    country = ["GHA","TGO"],
    export_format="geojson",
    force_redownload= True,
    max_cache_age_days=30  # Warn if data >30 days old
)

# Run extraction
processor = OSMHighwaysProcessor(config)
result = processor.process()
print(result)
# Out:
# 2025-11-04 17:36:34,232 - geoworkflow.OSMHighwaysProcessor - INFO - Filters: country=['GHA', 'TGO'], city=None
# 2025-11-04 17:36:34,312 - geoworkflow.OSMHighwaysProcessor - INFO -   Loading PBF for GHA...
# 2025-11-04 17:36:34,314 - geoworkflow.utils.geofabrik_utils - INFO - Downloading ghana from Geofabrik: https://download.geofabrik.de/africa/ghana-latest.osm.pbf
# Downloading ghana: 100%|██████████| 107M/107M [00:06<00:00, 15.4MB/s]
# 2025-11-04 17:36:42,925 - geoworkflow.utils.geofabrik_utils - INFO - Downloaded 101.9 MB to /home/sjs96_file_share/data/.cache/osm/ghana-latest.osm.pbf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 30
#      28 # Run extraction
#      29 processor = OSMHighwaysProcessor(config)
# ---> 30 result = processor.process()
#      31 print(result)
#
# File /home/sjs96_file_share/geoworkflow/src/geoworkflow/processors/extraction/osm_highways.py:161, in OSMHighwaysProcessor.process(self)
#     159 else:
#     160     geometries = self._load_single_geometry()   # Returns list with 1 item
# --> 161 return self._process_geometries(geometries)
#
# File /home/sjs96_file_share/geoworkflow/src/geoworkflow/processors/extraction/osm_highways.py:180, in OSMHighwaysProcessor._process_geometries(self, geometries)
#     178 for iso3, geom_list in by_country.items():
#     179     try:
# --> 180         pbf_data, _ = self._load_country_pbf(iso3)
#     181     except Exception as e:
#     182         for geom, name in geom_list:
#
# File /home/sjs96_file_share/geoworkflow/src/geoworkflow/processors/extraction/osm_highways.py:248, in OSMHighwaysProcessor._load_country_pbf(self, iso3)
#     240 pbf_path, metadata = get_cached_pbf(
#     241     region=region,
#     242     cache_dir=self.highways_config.pbf_cache_dir,
#     243     force_redownload=self.highways_config.force_redownload,
#     244     max_age_days=self.highways_config.max_cache_age_days
#     245 )
#     247 osm = pyrosm.OSM(str(pbf_path))
# --> 248 highways_data = osm.get_network(network_type="all")
#     250 if highways_data is None or len(highways_data) == 0:
#     251     raise ExtractionError(f"No highways found in {region} PBF")
#
# File /home/sjs96_file_share/miniforge3/envs/geoworkflow/lib/python3.10/site-packages/pyrosm/pyrosm.py:246, in OSM.get_network(self, network_type, extra_attributes, nodes, timestamp)
#     243     tags_as_columns += extra_attributes
#     245 # Read pbf
# --> 246 self._read_pbf(timestamp)
#     248 # Filter network data with given filter
#     249 edges, node_gdf = get_network_data(
#     250     self._node_coordinates,
#     251     self._way_records,
#    (...)
#     255     slice_to_segments=nodes,
#     256 )
#
# File /home/sjs96_file_share/miniforge3/envs/geoworkflow/lib/python3.10/site-packages/pyrosm/pyrosm.py:132, in OSM._read_pbf(self, timestamp)
#     129 self._set_current_time(timestamp)
#     131 if self._nodes is None or self._way_records is None:
# --> 132     self._get_pbf_elements(bounding_box)
#     133 elif self._timestamp_changed:
#     134     self._get_pbf_elements(bounding_box)
#
# File /home/sjs96_file_share/miniforge3/envs/geoworkflow/lib/python3.10/site-packages/pyrosm/pyrosm.py:109, in OSM._get_pbf_elements(self, bounding_box)
#     108 def _get_pbf_elements(self, bounding_box):
# --> 109     nodes, ways, relations, node_coordinates = parse_osm_data(
#     110         self.filepath,
#     111         bounding_box,
#     112         exclude_relations=False,
#     113         unix_time_filter=self._current_timestamp,
#     114     )
#     116     self._nodes = nodes
#     117     self._way_records = ways
#
# File /home/sjs96_file_share/miniforge3/envs/geoworkflow/lib/python3.10/site-packages/pyrosm/pbfreader.pyx:371, in pyrosm.pbfreader.parse_osm_data()
#
# File /home/sjs96_file_share/miniforge3/envs/geoworkflow/lib/python3.10/site-packages/pyrosm/pbfreader.pyx:377, in pyrosm.pbfreader.parse_osm_data()
#
# File /home/sjs96_file_share/miniforge3/envs/geoworkflow/lib/python3.10/site-packages/pyrosm/pbfreader.pyx:441, in pyrosm.pbfreader._parse_osm_data()
#
# File /home/sjs96_file_share/miniforge3/envs/geoworkflow/lib/python3.10/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File /home/sjs96_file_share/miniforge3/envs/geoworkflow/lib/python3.10/site-packages/pandas/core/frame.py:2187, in DataFrame.to_dict(self, orient, into, index)
#    2084 """
#    2085 Convert the DataFrame to a dictionary.
#    2086
#    (...)
#    2183  defaultdict(<class 'list'>, {'col1': 2, 'col2': 0.75})]
#    2184 """
#    2185 from pandas.core.methods.to_dict import to_dict
# -> 2187 return to_dict(self, orient, into=into, index=index)
#
# File /home/sjs96_file_share/miniforge3/envs/geoworkflow/lib/python3.10/site-packages/pandas/core/methods/to_dict.py:254, in to_dict(df, orient, into, index)
#     250     object_dtype_indices_as_set = set(box_native_indices)
#     251     is_object_dtype_by_index = [
#     252         i in object_dtype_indices_as_set for i in range(len(df.columns))
#     253     ]
# --> 254     return into_c(
#     255         (
#     256             t[0],
#     257             {
#     258                 columns[i]: maybe_box_native(v)
#     259                 if is_object_dtype_by_index[i]
#     260                 else v
#     261                 for i, v in enumerate(t[1:])
#     262             },
#     263         )
#     264         for t in df.itertuples(name=None)
#     265     )
#     266 else:
#     267     return into_c(
#     268         (t[0], dict(zip(df.columns, t[1:]))) for t in df.itertuples(name=None)
#     269     )
#
# File /home/sjs96_file_share/miniforge3/envs/geoworkflow/lib/python3.10/site-packages/pandas/core/methods/to_dict.py:261, in <genexpr>(.0)
#     250     object_dtype_indices_as_set = set(box_native_indices)
#     251     is_object_dtype_by_index = [
#     252         i in object_dtype_indices_as_set for i in range(len(df.columns))
#     253     ]
#     254     return into_c(
#     255         (
#     256             t[0],
#     257             {
#     258                 columns[i]: maybe_box_native(v)
#     259                 if is_object_dtype_by_index[i]
#     260                 else v
# --> 261                 for i, v in enumerate(t[1:])
#     262             },
#     263         )
#     264         for t in df.itertuples(name=None)
#     265     )
#     266 else:
#     267     return into_c(
#     268         (t[0], dict(zip(df.columns, t[1:]))) for t in df.itertuples(name=None)
#     269     )
#
# KeyboardInterrupt:
